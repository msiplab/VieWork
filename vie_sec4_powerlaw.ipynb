# %% [markdown]
# <a href="https://colab.research.google.com/github/shodimaggio/VieWork/blob/develop/vie_sec4_powerlaw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # べき乗測変換
#
# \begin{equation}
#   s = T(r) = (L-1)\left(\frac{r}{L-1}\right)^\gamma
# \end{equation}

# %% [markdown]
# ## 画像ファイルのアップロード

# %%
from google.colab import files
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-36e341e8-d5f5-455e-add1-88bdeee166a0" name="files[]" multiple disabled />
#      <output id="result-36e341e8-d5f5-455e-add1-88bdeee166a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving firenzeRgb.jpg to firenzeRgb.jpg

# %%
uploaded_file_name = next(iter(uploaded_file))
print(uploaded_file_name)
# Out:
# firenzeRgb.jpg

# %% [markdown]
# ## 画像の読み込み
# 画像処理ライブラリ Pillow (PIL) を利用

# %%
from PIL import Image
#画像をsampleを開く
img = Image.open(uploaded_file_name)
print(img.mode)
print(img.format)
print(img.size)
print(img.getbands())
# Out:
# RGB
# JPEG
# (816, 612)
# ('R', 'G', 'B')

# %% [markdown]
# ## 画像の表示
# 可視化ライブラリMatplotlibを利用

# %%
from matplotlib import pyplot as plt

plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 815.5, 611.5, -0.5)

# %% [markdown]
# ## グレースケール画像に変換

# %%
gray_img = img.convert('L')
plt.imshow(gray_img, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 815.5, 611.5, -0.5)
